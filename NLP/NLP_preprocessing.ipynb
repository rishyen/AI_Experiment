# %%
import pandas as pd
df=pd.read_csv(r"/content/twitter_comments.csv")

# %%
df.columns=['Tweet ID','entity','sentiment','Tweet content']

# %%
df.head()
# Out:
#    Tweet ID       entity sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
#
#                                        Tweet content
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
df.shape
# Out:
# (74681, 4)

# %%
df.dtypes
# Out:
# Tweet ID          int64
# entity           object
# sentiment        object
# Tweet content    object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 2700

# %%
df.drop_duplicates(keep=False, inplace=True)

# %%
df=df.dropna()
df.isnull().sum()
# *100/len(df)
# Out:
# Tweet ID         0
# entity           0
# sentiment        0
# Tweet content    0
# dtype: int64

# %%
df.head()
# Out:
#    Tweet ID       entity sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
#
#                                        Tweet content
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
tt=df[['Tweet content','sentiment']]

# %%
tt.head()
# Out:
#                                        Tweet content sentiment
# 0  I am coming to the borders and I will kill you...  Positive
# 1  im getting on borderlands and i will kill you ...  Positive
# 2  im coming on borderlands and i will murder you...  Positive
# 3  im getting on borderlands 2 and i will murder ...  Positive
# 4  im getting into borderlands and i can murder y...  Positive

# %% [markdown]
# ## Text preprocessing

# %% [markdown]
# ###Lower casing

# %%
tt.loc[:, 'Tweet content']=tt['Tweet content'].str.lower()

# %%
tt.head()
# Out:
#                                        Tweet content sentiment
# 0  i am coming to the borders and i will kill you...  Positive
# 1  im getting on borderlands and i will kill you ...  Positive
# 2  im coming on borderlands and i will murder you...  Positive
# 3  im getting on borderlands 2 and i will murder ...  Positive
# 4  im getting into borderlands and i can murder y...  Positive

# %% [markdown]
# ###Remove html tags

# %%
import re  #Regular Expressions
def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'', text)

# %%
tt['Tweet content'] = tt['Tweet content'].apply(remove_html_tags)
# Out:
# <ipython-input-20-70cd6d1e387b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt['Tweet content'] = tt['Tweet content'].apply(remove_html_tags)

# %% [markdown]
# ###Remove URLs

# %%
def remove_url(text):
    pattern = re.compile(r'https?://\S+|www.\.\S+')
    return pattern.sub(r'', text)

# %%
tt['Tweet content'] = tt['Tweet content'].apply(remove_url)
# Out:
# <ipython-input-22-79e7649e3702>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt['Tweet content'] = tt['Tweet content'].apply(remove_url)

# %% [markdown]
# ###Remove punctuations

# %%
import string,time
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
exclude = string.punctuation

# %%
def remove_punc1(text):
    return text.translate(str.maketrans('','',exclude))

# %%
tt['Tweet content'] = tt['Tweet content'].apply(remove_punc1)
# Out:
# <ipython-input-26-185d3079cf97>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt['Tweet content'] = tt['Tweet content'].apply(remove_punc1)

# %% [markdown]
# ### remove stopwords

# %%
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
def remove_stopwords(text):
    new_text = []

    for word in text.split():
        if word in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(word)
    x = new_text[:]
    new_text.clear()
    return " ".join(x)

# %%
tt['Tweet content'] = tt['Tweet content'].apply(remove_stopwords)
# Out:
# <ipython-input-31-54501eedd254>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt['Tweet content'] = tt['Tweet content'].apply(remove_stopwords)

# %% [markdown]
# ###Handling Emojis
# If we have emojis in the text, we have two options:
# Removing Emojis. (OR)
# Replacing emojis in the form of text

# %%
#handling emojis
import re
def remove_emoji(text):
    emoji_pattern = re.compile("["
                               "u\U0001F600-\U0001F64F"  # Emotions
                               "u\U0001F300-\U0001F5FF"  # Symbols & pictographs
                               "u\U0001F680-\U0001F6FF"  # Transport & map symbols
                               "u\U0001F1E0-\U0001F1FF"  # Flags(iOS)
                               "u\U00002702-\U000027B0"
                               "u\U000024C2-\U0001F251"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
# tt['Tweet content']=tt['Tweet content'].apply(remove_emoji)

# %%
# !pip install demoji
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 1.3 MB/s eta 0:00:00
# ...

# %%
# !pip install emoji
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 7.7 MB/s eta 0:00:00
# ...

# %%
#replace emoji
# Replace
import demoji
import emoji
def demojize(text):
    return demoji.replace(text)
# print(emoji.demojize(text))

# %%
tt['Tweet content']=tt['Tweet content'].apply(demojize)
# Out:
# <ipython-input-40-469739aebbfb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt['Tweet content']=tt['Tweet content'].apply(demojize)

# %% [markdown]
# ###Chat words/genz lingo

# %%
chat_word = {
    'AFAIK': 'As Far As I Know',
    'AFK': 'Away From Keyboard',
    'ASAP': 'As Soon As Possible',
    'ATK': 'At The Keyboard',
    'ATM': 'At The Moment',
    'A3': 'Anytime, Anywhere, Anyplace',
    'BAK': 'Back At Keyboard',
    'BBL': 'Be Back Later',
    'BBS': 'Be Back Soon',
    'BFN': 'Bye For Now',
    'B4N': 'Bye For Now',
    'BRB': 'Be Right Back',
    'BRT': 'Be Right There',
    'BTW': 'By The Way',
    'B4': 'Before',
    'CU': 'See You',
    'CUL8R': 'See You Later',
    'CYA': 'See You',
    'FAQ': 'Frequently Asked Questions',
    'FC': 'Fingers Crossed',
    'FWIW': "For What It's Worth",
    'FYI': 'For Your Information',
    'GAL': 'Get A Life',
    'GG': 'Good Game',
    'GN': 'Good Night',
    'GMTA': 'Great Minds Think Alike',
    'GR8': 'Great!',
    'G9': 'Genius',
    'IC': 'I See',
    'ICQ': 'I Seek you (also a chat program)',
    'ILU': 'ILU: I Love You',
    'IMHO': 'In My Honest/Humble Opinion',
    'IMO': 'In My Opinion',
    'IOW': 'In Other Words',
    'IRL': 'In Real Life',
    'KISS': 'Keep It Simple, Stupid',
    'LDR': 'Long Distance Relationship',
    'LMAO': 'Laugh My A.. Off',
    'LOL': 'Laughing Out Loud',
    'LTNS': 'Long Time No See',
    'L8R': 'Later',
    'MTE': 'My Thoughts Exactly',
    'M8': 'Mate',
    'NRN': 'No Reply Necessary',
    'OIC': 'Oh I See',
    'PITA': 'Pain In The A..',
    'PRT': 'Party',
    'PRW': 'Parents Are Watching',
    'QPSA?': 'Que Pasa?',
    'ROFL': 'Rolling On The Floor Laughing',
    'ROFLOL': 'Rolling On The Floor Laughing Out Loud',
    'ROTFLMAO': 'Rolling On The Floor Laughing My A.. Off',
    'SK8': 'Skate',
    'STATS': 'Your sex and age',
    'ASL': 'Age, Sex, Location',
    'THX': 'Thank You',
    'TTFN': 'Ta-Ta For Now!',
    'TTYL': 'Talk To You Later',
    'U': 'You',
    'U2': 'You Too',
    'U4E': 'Yours For Ever',
    'WB': 'Welcome Back',
    'WTF': 'What The F...',
    'WTG': 'Way To Go!',
    'WUF': 'Where Are You From?',
    'W8': 'Wait...',
    '7K': 'Sick:-D Laugher',
    'TFW': 'That feeling when',
    'MFW': 'My face when',
    'MRW': 'My reaction when',
    'IFYP': 'I feel your pain',
    'TNTL': 'Trying not to laugh',
    'JK': 'Just kidding',
    'IDC': "I don't care",
    'ILY': 'I love you',
    'IMU': 'I miss you',
    'ADIH': 'Another day in hell',
    'ZZZ': 'Sleeping, bored, tired',
    'WYWH': 'Wish you were here',
    'TIME': 'Tears in my eyes',
    'BAE': 'Before anyone else',
    'FIMH': 'Forever in my heart',
    'BSAAW': 'Big smile and a wink',
    'BWL': 'Bursting with laughter',
    'BFF': 'Best friends forever',
    'CSL': "Can't stop laughing"
}

# %%
def short_conv(text):
    new_text = []
    for w in text.split():
        if w.upper() in chat_word:
            new_text.append(chat_word[w.upper()])
        else:
            new_text.append(w)
    return " ".join(new_text)

# %%
tt['Tweet content']=tt['Tweet content'].apply(short_conv)
# Out:
# <ipython-input-43-b25ccaee60e4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt['Tweet content']=tt['Tweet content'].apply(short_conv)

# %% [markdown]
# ###Tonkenization

# %%
tt.head()
# Out:
#                      Tweet content sentiment
# 0              coming borders kill  Positive
# 1      im getting borderlands kill  Positive
# 2     im coming borderlands murder  Positive
# 3  im getting borderlands 2 murder  Positive
# 4    im getting borderlands murder  Positive

# %% [markdown]
# ###Stemming

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
def stem_words(text):
    return " ".join([ps.stem(word) for word in text.split()])

# %%
tt['Tweet content'] = tt['Tweet content'].apply(lambda x: stem_words(x))
# Out:
# <ipython-input-46-29a18e0ece06>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt['Tweet content'] = tt['Tweet content'].apply(lambda x: stem_words(x))

# %% [markdown]
# ###Lemming&pos tagging

# %%
import nltk
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

# Download the WordNet corpus
nltk.download('wordnet')

# You might also need to download the 'omw-1.4' package for wordnet
nltk.download('omw-1.4')

# Download the averaged_perceptron_tagger
nltk.download('averaged_perceptron_tagger_eng') # This line is added

lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V": wordnet.VERB, "J": wordnet.ADJ, "R": wordnet.ADV}

def lemmatize_words(text):
    # find pos tags
    pos_text = pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_text])

tt['Tweet content'] = tt['Tweet content'].apply(lambda x: lemmatize_words(x))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# <ipython-input-47-2d70cbf04d54>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt['Tweet content'] = tt['Tweet content'].apply(lambda x: lemmatize_words(x))

# %%
tt.sample(10)
# Out:
#                                            Tweet content   sentiment
# 49304  wouldn’t even play format fifa y’all complet d...    Negative
# 26784                              kind weird still miss    Positive
# 4193   black op cold war definit step modern warfar t...    Negative
# 37252                        ok explain death damn scari    Negative
# 9344   pretti cool see new next gen game announc play...    Positive
# 12966              complic often stay bed hoop hoop hoop  Irrelevant
# 55655  im happili go game dude throw holi hand grenad...     Neutral
# 2518   anyon book dvd beta weekend gonna absolut best...    Positive
# 2396   know historyunless involv chinabecaus likew in...     Neutral
# 68649  nice hot littl youtub in real life look big de...    Positive

# %% [markdown]
# ### spelling correction

# %%
# from textblob import TextBlob

# text=" ceertainli  kniw wrrong herre"
# textblb=TextBlob(text)
# textblb.correct().string

# %%
# !pip install textblob
# !python -m textblob.download_corpora
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.3/624.3 kB 7.0 MB/s eta 0:00:00
# ...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.

# %%
from textblob import TextBlob
def correct_spelling(text):
    textblb=TextBlob(text)
    return textblb.correct().string
tt['Tweet content'] = tt['Tweet content'].apply(correct_spelling)

# %%
# !pip install pyspellchecker

# %%
# from spellchecker import SpellChecker
# spell = SpellChecker()

# def correct_spellings(text):
#     corrected_text = []
#     misspelled_text = spell.unknown(text.split())
#     # print(misspelled_text)
#     for word in text.split():
#         if word in misspelled_text:
#             # Get the correction, or keep the original word if None
#             correction = spell.correction(word)
#             corrected_text.append(correction if correction is not None else word)
#         else:
#             corrected_text.append(word)

#     return " ".join(corrected_text)

# tt['Tweet content'] = tt['Tweet content'].apply(correct_spellings)

# %%
tt.sample(10)

# %% [markdown]
# ##Feature engg

# %% [markdown]
# ###Bagofwords

# %% [markdown]
# ###Countvectorizer

# %%
from sklearn.feature_extraction.text import  CountVectorizer

df1=df

no_features = 1000
tf_vectorizer = CountVectorizer( max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(df1.words_sentences)

# %%
df_x=pd.DataFrame(tf.A, columns=tf_vectorizer.get_feature_names())

# %% [markdown]
# ###TFIDVectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(df.words_sentences)

X = pd.DataFrame(tfidf_matrix.todense(), columns=tfidf_vectorizer.get_feature_names())
